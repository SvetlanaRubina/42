# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_log_error
from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import xgboost

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# Drop outliers:

# %%
out_index = train[(train.GrLivArea > 4000) & (train.SalePrice < 200000)].index

# %%
train.drop(out_index, axis=0, inplace=True)

# %%
#train = train[train['GrLivArea'] <= 4000]
train.loc[train['LotArea'] > 30000, 'LotArea'] = 30000

# %% [markdown]
# FillNA

# %%
for col in train.columns:
    if train[col].dtype == 'object':
        train[col].fillna('N_A', inplace=True)
    else:
        train[col].fillna(0, inplace=True)

# %% [markdown]
# Feature conversion:

# %%
mapping = {'N_A': 0, 
           'Po': 1, 
           'Fa': 2, 
           'TA': 3, 
           'Gd': 4, 
           'Ex': 5}

# %%
for col in train.columns:
    if train[col].unique().any() in ['TA', 'Gd', 'Fa', 'Po', 'Ex']:
        train[col] = train[col].map(mapping)

# %%
train['FireplaceQu'] = train['FireplaceQu'].map(mapping)

# %% [raw]
# train['AreaQual'] = train['GrLivArea'] * train['OverallQual'] * train['OverallCond']
# train['FireplaceQual'] = train['Fireplaces'] * train['FireplaceQu']
# train['Bath'] = train['FullBath'] + 0.5 * train['HalfBath']
# train['BsmtQuCondSF'] = train['TotalBsmtSF'] * train['BsmtCond'] * train['BsmtQual']
# train['DeckPorchSF'] = train[['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].sum(axis=1)

# %% [raw]
# train['AreaQual'] = train['GrLivArea'] * train['OverallQual'] * train['OverallCond']
# train['FireplaceQual'] = train['Fireplaces'] * train['FireplaceQu']
# train['Bath'] = train['FullBath'] + 0.5 * train['HalfBath']
# train['BsmtQuCondSF'] = train['TotalBsmtSF'] * train['BsmtCond'] * train['BsmtQual']
# train['DeckPorchSF'] = train[['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].sum(axis=1)
# train['TotalLivingSF'] = train['1stFlrSF'] + train['2ndFlrSF']
# train['BsmtBath'] = train['BsmtFullBath'] + 0.5 * train['BsmtHalfBath']
# train['ExterQC'] = train['ExterQual'] + train['ExterCond']
# train['KitchenQC'] = train['KitchenAbvGr'] * train['KitchenQual']

# %% [raw]
# train['GarageQu'] = train['GarageQual'] * train['GarageArea']

# %% [markdown]
# Drop unnecessaries

# %%
train.drop('Id', axis=1, inplace=True)

# %%
train.drop('LotFrontage', axis=1, inplace=True)

# %%
train
# Out:
#       MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0             60       RL     8450   Pave   N_A      Reg         Lvl
# 1             20       RL     9600   Pave   N_A      Reg         Lvl
# 2             60       RL    11250   Pave   N_A      IR1         Lvl
# 3             70       RL     9550   Pave   N_A      IR1         Lvl
# 4             60       RL    14260   Pave   N_A      IR1         Lvl
# ...          ...      ...      ...    ...   ...      ...         ...
# 1455          60       RL     7917   Pave   N_A      Reg         Lvl
# 1456          20       RL    13175   Pave   N_A      Reg         Lvl
# 1457          70       RL     9042   Pave   N_A      Reg         Lvl
# 1458          20       RL     9717   Pave   N_A      Reg         Lvl
# 1459          20       RL     9937   Pave   N_A      Reg         Lvl
#
#      Utilities LotConfig LandSlope Condition1 Condition2 BldgType HouseStyle  \
# 0       AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 1       AllPub       FR2       Gtl      Feedr       Norm     1Fam     1Story
# 2       AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 3       AllPub    Corner       Gtl       Norm       Norm     1Fam     2Story
# 4       AllPub       FR2       Gtl       Norm       Norm     1Fam     2Story
# ...        ...       ...       ...        ...        ...      ...        ...
# 1455    AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 1456    AllPub    Inside       Gtl       Norm       Norm     1Fam     1Story
# 1457    AllPub    Inside       Gtl       Norm       Norm     1Fam     2Story
# 1458    AllPub    Inside       Gtl       Norm       Norm     1Fam     1Story
# 1459    AllPub    Inside       Gtl       Norm       Norm     1Fam     1Story
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0               7            5       2003          2003     Gable  CompShg
# 1               6            8       1976          1976     Gable  CompShg
# 2               7            5       2001          2002     Gable  CompShg
# 3               7            5       1915          1970     Gable  CompShg
# 4               8            5       2000          2000     Gable  CompShg
# ...           ...          ...        ...           ...       ...      ...
# 1455            6            5       1999          2000     Gable  CompShg
# 1456            6            6       1978          1988     Gable  CompShg
# 1457            7            9       1941          2006     Gable  CompShg
# 1458            5            6       1950          1996       Hip  CompShg
# 1459            5            6       1965          1965     Gable  CompShg
#
#      Exterior1st Exterior2nd MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0        VinylSd     VinylSd    BrkFace       196.0          4          3
# 1        MetalSd     MetalSd       None         0.0          3          3
# 2        VinylSd     VinylSd    BrkFace       162.0          4          3
# 3        Wd Sdng     Wd Shng       None         0.0          3          3
# 4        VinylSd     VinylSd    BrkFace       350.0          4          3
# ...          ...         ...        ...         ...        ...        ...
# 1455     VinylSd     VinylSd       None         0.0          3          3
# 1456     Plywood     Plywood      Stone       119.0          3          3
# 1457     CemntBd     CmentBd       None         0.0          5          4
# 1458     MetalSd     MetalSd       None         0.0          3          3
# 1459     HdBoard     HdBoard       None         0.0          4          3
#
#      Foundation  BsmtQual  BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0         PConc         4         3           No          GLQ         706
# 1        CBlock         4         3           Gd          ALQ         978
# 2         PConc         4         3           Mn          GLQ         486
# 3        BrkTil         3         4           No          ALQ         216
# 4         PConc         4         3           Av          GLQ         655
# ...         ...       ...       ...          ...          ...         ...
# 1455      PConc         4         3           No          Unf           0
# 1456     CBlock         4         3           No          ALQ         790
# 1457      Stone         3         4           No          GLQ         275
# 1458     CBlock         3         3           Mn          GLQ          49
# 1459     CBlock         3         3           No          BLQ         830
#
#      BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  HeatingQC  \
# 0             Unf           0        150          856    GasA          5
# 1             Unf           0        284         1262    GasA          5
# 2             Unf           0        434          920    GasA          5
# 3             Unf           0        540          756    GasA          4
# 4             Unf           0        490         1145    GasA          5
# ...           ...         ...        ...          ...     ...        ...
# 1455          Unf           0        953          953    GasA          5
# 1456          Rec         163        589         1542    GasA          3
# 1457          Unf           0        877         1152    GasA          5
# 1458          Rec        1029          0         1078    GasA          4
# 1459          LwQ         290        136         1256    GasA          4
#
#      CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0             Y      SBrkr       856       854             0       1710
# 1             Y      SBrkr      1262         0             0       1262
# 2             Y      SBrkr       920       866             0       1786
# 3             Y      SBrkr       961       756             0       1717
# 4             Y      SBrkr      1145      1053             0       2198
# ...         ...        ...       ...       ...           ...        ...
# 1455          Y      SBrkr       953       694             0       1647
# 1456          Y      SBrkr      2073         0             0       2073
# 1457          Y      SBrkr      1188      1152             0       2340
# 1458          Y      FuseA      1078         0             0       1078
# 1459          Y      SBrkr      1256         0             0       1256
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0                1             0         2         1             3
# 1                0             1         2         0             3
# 2                1             0         2         1             3
# 3                1             0         1         0             3
# 4                1             0         2         1             4
# ...            ...           ...       ...       ...           ...
# 1455             0             0         2         1             3
# 1456             1             0         2         0             3
# 1457             0             0         2         0             4
# 1458             1             0         1         0             2
# 1459             1             0         1         1             3
#
#       KitchenAbvGr  KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 0                1            4             8        Typ           0
# 1                1            3             6        Typ           1
# 2                1            4             6        Typ           1
# 3                1            4             7        Typ           1
# 4                1            4             9        Typ           1
# ...            ...          ...           ...        ...         ...
# 1455             1            3             7        Typ           1
# 1456             1            3             7       Min1           2
# 1457             1            4             9        Typ           2
# 1458             1            4             5        Typ           0
# 1459             1            3             6        Typ           0
#
#       FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 0               0     Attchd       2003.0          RFn           2
# 1               3     Attchd       1976.0          RFn           2
# 2               3     Attchd       2001.0          RFn           2
# 3               4     Detchd       1998.0          Unf           3
# 4               3     Attchd       2000.0          RFn           3
# ...           ...        ...          ...          ...         ...
# 1455            3     Attchd       1999.0          RFn           2
# 1456            3     Attchd       1978.0          Unf           2
# 1457            4     Attchd       1941.0          RFn           1
# 1458            0     Attchd       1950.0          Unf           1
# 1459            0     Attchd       1965.0          Fin           1
#
#       GarageArea  GarageQual  GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0            548           3           3          Y           0           61
# 1            460           3           3          Y         298            0
# 2            608           3           3          Y           0           42
# 3            642           3           3          Y           0           35
# 4            836           3           3          Y         192           84
# ...          ...         ...         ...        ...         ...          ...
# 1455         460           3           3          Y           0           40
# 1456         500           3           3          Y         349            0
# 1457         252           3           3          Y           0           60
# 1458         240           3           3          Y         366            0
# 1459         276           3           3          Y         736           68
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence  \
# 0                 0          0            0         0    N_A    N_A
# 1                 0          0            0         0    N_A    N_A
# 2                 0          0            0         0    N_A    N_A
# 3               272          0            0         0    N_A    N_A
# 4                 0          0            0         0    N_A    N_A
# ...             ...        ...          ...       ...    ...    ...
# 1455              0          0            0         0    N_A    N_A
# 1456              0          0            0         0    N_A  MnPrv
# 1457              0          0            0         0    N_A  GdPrv
# 1458            112          0            0         0    N_A    N_A
# 1459              0          0            0         0    N_A    N_A
#
#      MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 0            N_A        0       2    2008       WD        Normal     208500
# 1            N_A        0       5    2007       WD        Normal     181500
# 2            N_A        0       9    2008       WD        Normal     223500
# 3            N_A        0       2    2006       WD       Abnorml     140000
# 4            N_A        0      12    2008       WD        Normal     250000
# ...          ...      ...     ...     ...      ...           ...        ...
# 1455         N_A        0       8    2007       WD        Normal     175000
# 1456         N_A        0       2    2010       WD        Normal     210000
# 1457        Shed     2500       5    2010       WD        Normal     266500
# 1458         N_A        0       4    2010       WD        Normal     142125
# 1459         N_A        0       6    2008       WD        Normal     147500
#
#       neighborhoods_ordinal
# 0                      17.0
# 1                      20.0
# 2                      17.0
# 3                      19.0
# 4                      24.0
# ...                     ...
# 1455                   14.0
# 1456                   15.0
# 1457                   19.0
# 1458                   10.0
# 1459                    5.0
#
# [1458 rows x 79 columns]

# %% [markdown]
# Transformation into ordinal feature:

# %%
neighborhoods = (train.groupby('Neighborhood')['SalePrice']
                 .agg(['mean', 'median', 'count'])
                 .sort_values(by='median', ascending=False))

# %%
n_sorted = neighborhoods.sort_values(by='median').index

# %%
for i, n in enumerate(n_sorted):
    train.loc[train['Neighborhood'] == n, 'neighborhoods_ordinal'] = int(i+1)

# %%
train.drop('Neighborhood', axis=1, inplace=True)

# %% [raw]
# train.drop([
#  'BsmtUnfSF',
#  'BsmtFinType1',
#  'BsmtFinSF2', 'BsmtFinSF1',
#  'GarageYrBlt',
#  'BsmtFinType2',
#     'OverallCond',
#     'TotalBsmtSF', 'BsmtCond', 'BsmtQual',
#     'YrSold',
#     'YearBuilt',
#     'GarageCars',
#     'YearRemodAdd',
#     'OverallQual',
#     'GrLivArea',
#     'Fireplaces', 'FireplaceQu',
#     'FullBath', 'HalfBath',
#     'GarageQual', 'GarageArea',
#     'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch',
#     #'1stFlrSF', '2ndFlrSF',########
# #'BsmtFullBath', 'BsmtHalfBath',
# #'ExterQual', 'ExterCond',
# #'KitchenAbvGr', 'KitchenQual',
# ], axis=1, inplace=True)

# %% [raw]
# for col in list(train.columns):
#     sns.scatterplot(x=col, y='SalePrice', s=15, data=train.sort_values(by='SalePrice'))
#     plt.show()

# %%
#train['AreaQual'] = np.log(train['AreaQual'])
#train['DeckPorchSF'] = np.log(train['DeckPorchSF'])
#train['TotalLivingSF'] = np.log(train['TotalLivingSF'])
#train['SalePrice'] = np.log(train['SalePrice'])

# %% [raw]
# fig = plt.figure(figsize = (15,20))
# ax = fig.gca()
# train.hist(ax = ax, bins=30)
# plt.show()

# %% [markdown]
# ### Modeling

# %%
def extract_cat_features(data):
    cat_features = []
    num_features = []
    for i, col in enumerate(data.columns):
        if data[col].dtype == 'object':
            cat_features.append(col)
        else:
            num_features.append(col)
    return cat_features, num_features

# %%
def prepare_and_split_data(input_data, test_size=0):
    data = input_data.copy()
    for col in data.columns:
        if data[col].dtype == 'object':
            data[col].fillna('N_A', inplace=True)
        else:
            data[col].fillna(0, inplace=True)
    X = data.drop('SalePrice', axis=1)
    y = data['SalePrice']
    if test_size > 0:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
        return X_train, X_test, y_train, y_test
    else:
        return X, y

# %%
cat_features, num_features = extract_cat_features(train)

# %%
X_train, X_test, y_train, y_test = prepare_and_split_data(train, test_size=.25)

# %%
# initialize Pool
train_pool = Pool(X_train, 
                  y_train, 
                  cat_features=cat_features)

eval_pool = Pool(X_test, 
                 y_test, 
                 cat_features=cat_features)

# specify the training parameters 
model = CatBoostRegressor(iterations=1000, 
                          depth=2, 
                          learning_rate=0.1, 
                          loss_function='MAE',
                          l2_leaf_reg=5,
                          one_hot_max_size=30,
                          random_state=42,
                          random_strength=1,                          
                          verbose=100
                          )
#train the model
model.fit(train_pool, eval_set=eval_pool)
# make the prediction using the resulting model
preds = model.predict(eval_pool)
print(f'RMSE: {np.sqrt(mean_squared_error(preds, y_test))}')
print(f'LRMSE: {np.sqrt(mean_squared_log_error(preds, y_test))}')
print(f'R2: {r2_score(preds, y_test)}')
# Out:
# 0:	learn: 52215.6394775	test: 52890.9150171	best: 52890.9150171 (0)	total: 1.33ms	remaining: 1.33s
# 100:	learn: 15244.4544278	test: 16286.9045128	best: 16278.1440864 (98)	total: 54.2ms	remaining: 482ms
# 200:	learn: 12915.3986154	test: 15254.9031813	best: 15254.9031813 (200)	total: 99.4ms	remaining: 395ms
# 300:	learn: 11903.3799953	test: 14849.6729582	best: 14847.8364001 (299)	total: 145ms	remaining: 337ms
# 400:	learn: 11251.2725892	test: 14668.0637213	best: 14655.0590792 (390)	total: 188ms	remaining: 282ms
# 500:	learn: 10793.9820364	test: 14497.7179588	best: 14494.6637828 (499)	total: 232ms	remaining: 231ms
# 600:	learn: 10328.1927707	test: 14352.7593171	best: 14351.7820086 (599)	total: 274ms	remaining: 182ms
# 700:	learn: 10052.2082395	test: 14311.0494876	best: 14311.0494876 (700)	total: 316ms	remaining: 135ms
# 800:	learn: 9715.1984317	test: 14174.1808572	best: 14174.1808572 (800)	total: 358ms	remaining: 88.9ms
# 900:	learn: 9482.6172438	test: 14116.3371660	best: 14107.0297143 (848)	total: 399ms	remaining: 43.8ms
# 999:	learn: 9299.8967816	test: 14078.2373193	best: 14075.9060759 (993)	total: 441ms	remaining: 0us
#
# bestTest = 14075.90608
# bestIteration = 993
#
# Shrink model to first 994 iterations.
# RMSE: 20650.512519121356
# LRMSE: 0.11125079095296522
# R2: 0.9247676969947811

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(preds)), (preds - y_test))
plt.axhline(0, c='r')
plt.axhline(20000, c='g')
plt.axhline(-20000, c='g')

# %%
model.get_feature_importance(prettified=True)
# Out:
#                Feature Id  Importances
# 0               GrLivArea    19.178299
# 1             OverallQual    17.149080
# 2   neighborhoods_ordinal    10.817781
# 3               ExterQual     5.907347
# 4             TotalBsmtSF     5.752781
# 5                1stFlrSF     4.538599
# 6             KitchenQual     3.828896
# 7                BsmtQual     3.696430
# 8              BsmtFinSF1     3.670921
# 9              GarageCars     3.172961
# 10             Fireplaces     2.617677
# 11             GarageArea     2.570599
# 12                LotArea     2.391115
# 13            GarageYrBlt     1.804684
# 14              YearBuilt     1.528799
# 15            OverallCond     1.159356
# 16               FullBath     0.955929
# 17           YearRemodAdd     0.698147
# 18             GarageType     0.662590
# 19             WoodDeckSF     0.655350
# 20           BsmtExposure     0.654936
# 21               2ndFlrSF     0.511214
# 22            OpenPorchSF     0.431435
# 23           BsmtFullBath     0.344402
# 24             MSSubClass     0.313405
# 25             HouseStyle     0.291321
# 26               SaleType     0.281222
# 27             MasVnrArea     0.271179
# 28               HalfBath     0.266584
# 29                 MoSold     0.263147
# 30             Functional     0.259781
# 31           BedroomAbvGr     0.247190
# 32             CentralAir     0.231661
# 33           TotRmsAbvGrd     0.219111
# 34            Exterior1st     0.208758
# 35             Condition1     0.208241
# 36              LotConfig     0.205581
# 37          SaleCondition     0.192299
# 38            ScreenPorch     0.160419
# 39             GarageCond     0.159013
# 40               BsmtCond     0.135282
# 41              RoofStyle     0.130548
# 42            Exterior2nd     0.108517
# 43              BsmtUnfSF     0.106497
# 44           BsmtFinType1     0.093162
# 45               MSZoning     0.088185
# 46           KitchenAbvGr     0.087971
# 47            FireplaceQu     0.087748
# 48             GarageQual     0.086950
# 49             BsmtFinSF2     0.070533
# 50                 YrSold     0.063936
# 51          EnclosedPorch     0.055366
# 52               RoofMatl     0.054187
# 53              3SsnPorch     0.050454
# 54             PavedDrive     0.049293
# 55             MasVnrType     0.048754
# 56               BldgType     0.042739
# 57              LandSlope     0.032931
# 58                  Fence     0.024574
# 59            LandContour     0.021650
# 60           BsmtFinType2     0.020615
# 61               LotShape     0.013112
# 62                 Street     0.011321
# 63             Foundation     0.010736
# 64                MiscVal     0.007745
# 65                  Alley     0.003921
# 66              HeatingQC     0.003711
# 67             Electrical     0.003617
# 68           BsmtHalfBath     0.002972
# 69           GarageFinish     0.002076
# 70              ExterCond     0.002051
# 71            MiscFeature     0.000399
# 72           LowQualFinSF     0.000087
# 73                Heating     0.000082
# 74             Condition2     0.000033
# 75              Utilities     0.000000
# 76               PoolArea     0.000000
# 77                 PoolQC     0.000000

# %%
def data_preprocessing(data_train, test_size=.25):
    X_train, X_test, y_train, y_test = train_test_split(data_train.drop('SalePrice', axis=1), 
                                                        data_train['SalePrice'], 
                                                        test_size=test_size, 
                                                        random_state=42)
    categories = []
    for col in data_train.columns:
        if data_train[col].dtype == 'object':
            categories.append(col)
    ohe = OneHotEncoder(handle_unknown='infrequent_if_exist')
    ohe.fit(X_train[categories])
    cat_features_df = pd.DataFrame(ohe.transform(X_train[categories]).toarray(), 
                                   index=X_train.index, 
                                   columns=ohe.get_feature_names_out())
    X_train.drop(categories, axis=1, inplace=True)
    X = X_train.join(cat_features_df)
    test_cat_features_df = pd.DataFrame(ohe.transform(X_test[categories]).toarray(), 
                                        index=X_test.index, 
                                        columns=ohe.get_feature_names_out())
    X_test.drop(categories, axis=1, inplace=True)
    X_t = X_test.join(test_cat_features_df)
    return X, X_t, y_train, y_test

# %%
X_train1, X_test1, y_train1, y_test1 = data_preprocessing(train, test_size=.25)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train1)
# Out:
# StandardScaler()

# %%
X_train1_s = scaler.transform(X_train1)
X_test1_s = scaler.transform(X_test1)

# %%
y_train_log = np.log(y_train1)
y_test_log = np.log(y_test1)

# %%
from sklearn.linear_model import Lasso, LinearRegression, Ridge

# %%
lasso = Lasso(alpha=10.0, 
      fit_intercept=True, 
      precompute=False, 
      copy_X=True, 
      max_iter=5000, 
      tol=0.0001, 
      warm_start=False, 
      positive=False, 
      random_state=42, 
      selection='random')

# %%
lasso.fit(X_train1_s, y_train1)
# Out:
# /Users/gdyskin/opt/anaconda3/envs/YDATA/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.715e+10, tolerance: 6.971e+08
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=10.0, max_iter=5000, random_state=42, selection='random')

# %%
lasso_preds = lasso.predict(X_test1_s)

# %%
np.sqrt(mean_squared_error(lasso.predict(X_test1_s), y_test1))
# Out:
# 32260.565900546597

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(y_test1)), lasso.predict(X_test1_s) - y_test1)
plt.axhline(0, c='r')
plt.axhline(20000, c='g')
plt.axhline(-20000, c='g')

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='linear', 
          degree=1, 
          gamma='scale', 
          coef0=0.0, 
          tol=0.001, 
          C=300.0, 
          epsilon=0.1, 
          shrinking=True, 
          cache_size=200, 
          verbose=False, 
          max_iter=1000)

# %%
svr.fit(X_train1_s, y_train1)
# Out:
# /Users/gdyskin/opt/anaconda3/envs/YDATA/lib/python3.10/site-packages/sklearn/svm/_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVR(C=300.0, degree=1, kernel='linear', max_iter=1000)

# %%
svr_preds = svr.predict(X_test1_s)

# %%
np.sqrt(mean_squared_error(svr.predict(X_test1_s), y_test1))
# Out:
# 29480.38102246769

# %%
np.sqrt(mean_squared_log_error(svr.predict(X_test1_s), y_test1))
# Out:
# 0.162025488214886

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(y_test1)), svr.predict(X_test1_s) - y_test1)
plt.axhline(0, c='r')
plt.axhline(20000, c='g')
plt.axhline(-20000, c='g')

# %%
ridge = Ridge(alpha=22.9, 
      fit_intercept=True, 
      copy_X=True, 
      max_iter=None, 
      tol=0.0001, 
      solver='auto', 
      positive=False, 
      random_state=42)

# %%
ridge.fit(X_train1_s, y_train1)
# Out:
# Ridge(alpha=22.9, random_state=42)

# %%
ridge_preds = ridge.predict(X_test1_s)

# %%
np.sqrt(mean_squared_error(ridge.predict(X_test1_s), y_test1))
# Out:
# 30909.85554139832

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(y_test1)), ridge.predict(X_test1_s) - y_test1)
plt.axhline(0, c='r')
plt.axhline(20000, c='g')
plt.axhline(-20000, c='g')

# %% [markdown]
# ### XGboost

# %%
model_xgb = xgboost.XGBRegressor(max_depth=3, 
                                 booster="gbtree", 
                                 learning_rate=0.1, 
                                 subsample=0.3, 
                                 reg_lambda=5, 
                                 n_estimators=100)
model_xgb.fit(X_train1_s, y_train1)
test_predictions = model_xgb.predict(X_test1_s)

np.sqrt(mean_squared_error(y_test1, test_predictions))
# Out:
# 23970.142185901652

# %%
np.sqrt(mean_squared_log_error(model_xgb.predict(X_test1_s), y_test1))
# Out:
# 0.12817053512935492

# %%
plt.figure(figsize=(20,10))
plt.scatter(range(len(y_test1)), model_xgb.predict(X_test1_s) - y_test1)
plt.axhline(0, c='r')
plt.axhline(20000, c='g')
plt.axhline(-20000, c='g')

# %% [markdown]
# ### An attempt to ensemble learning

# %% [markdown]
# ### Submission

# %%
X, y = prepare_and_split_data(train)

# %%
sub_train_pool = Pool(X, y, 
                 cat_features=cat_features)

# %%
model.fit(sub_train_pool)
# Out:
# 0:	learn: 52572.5760868	total: 1.25ms	remaining: 1.25s
# 100:	learn: 15474.3934416	total: 65.8ms	remaining: 586ms
# 200:	learn: 13249.3006935	total: 114ms	remaining: 455ms
# 300:	learn: 12276.0171442	total: 163ms	remaining: 378ms
# 400:	learn: 11586.8355020	total: 211ms	remaining: 316ms
# 500:	learn: 11131.8798871	total: 260ms	remaining: 259ms
# 600:	learn: 10799.5476545	total: 308ms	remaining: 204ms
# 700:	learn: 10513.4866373	total: 355ms	remaining: 152ms
# 800:	learn: 10224.5101396	total: 404ms	remaining: 100ms
# 900:	learn: 9995.1682389	total: 452ms	remaining: 49.6ms
# 999:	learn: 9768.6605726	total: 497ms	remaining: 0us

# %%
test = pd.read_csv('test_preprocessed.csv')

# %%
preds = model.predict(test)

# %%
preds
# Out:
# array([129632.29308877, 158763.27128026, 183355.13452465, ...,
#        161218.26651025, 121440.24678895, 217120.18312224])

# %%
test_id = pd.read_csv('test.csv')

# %%
sub_test = test_id.copy()

# %%
sub_test['SalePrice'] = pd.Series(preds)

# %% [markdown]
# ### Output

# %%
#sub_test[['Id', 'SalePrice']].to_csv('out.csv', index=False)
